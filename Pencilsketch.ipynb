# %% [markdown]
# **LGMVIP - Data Science Intern**
#
# **Beginner Level Task 1 - Image to Pencil Sketch with Python**
#
# **Author - Kavita Dnyanoba Samdade**

# %%
from google.colab.patches import cv2_imshow
import cv2

# %%
img= cv2.imread('/content/classical dance.jpg' , 1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F5E2E8D9CD0>

# %%
img_gray =cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F5E1FA67FD0>

# %%
img_invert = cv2.bitwise_not(img_gray)
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F5E1FA6E350>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F5E1FA748D0>

# %%
def dodgeV2(x, y):
  return cv2.divide(x,255-y,scale=256)

# %%
final_img = dodgeV2(img_gray,img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F5E1FA92350>
